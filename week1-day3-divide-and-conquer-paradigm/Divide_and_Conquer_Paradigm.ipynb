# %% [markdown]
# # ⭐ You have 1 million sorted numbers. How do you search a number?
#
# ---
#
# # ⭐ Divide and Conquer
#
# 1. Divide problem into smaller subproblems
# 2. Conquer (solve recursively)
# 3. Combine results
#
#
# ## T(n) = aT(n/b) + f(n)
#
# - a → number of subproblems
# - n/b → size of each
# - f(n) → combine cost

# %% [markdown]
# # 1️⃣ Bubble Sort

# %%
def bubble_sort(arr):
    n = len(arr) # 1
    for i in range(n): # n
        for j in range(0, n - i - 1): # n^2
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

#  0  1  2  3  4  5  6
# [1, 2, 3, 4, 5, 6, 7] = n = 7

# bubble_sort([5,1,8,2,0,4,8,3])

# %% [markdown]
# ### Recurrence Relation
# T(n)=T(n−1)+O(n)
#
# ### Time Complexity
# O(n^2)

# %% [markdown]
# # 2️⃣ Merge Sort

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)


def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

# merge_sort([5,1,8,2,0,4,8,3])

# %% [markdown]
# ![Image20260219000853.png](data:image/png;base64,...)

# %% [markdown]
# ### Recurrence Relation
# T(n)=2T(n/2)+O(n)
#
# ### Time Complexity
# O(n log n)

# %% [markdown]
# # 3️⃣ Binary Search

# %%
# Iterative Version

def binary_search(arr, target):
    left, right = 0, len(arr) - 1

    while left <= right:
        mid = (left + right) // 2

        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1

    return -1

# binary_search([1, 2, 3, 4, 5, 6, 7, 8], 4)

# %%
# Recursive Version

def binary_search_recursive(arr, left, right, target):
    if left > right:
        return -1

    mid = (left + right) // 2

    if arr[mid] == target:
        return mid
    elif arr[mid] < target:
        return binary_search_recursive(arr, mid + 1, right, target)
    else:
        return binary_search_recursive(arr, left, mid - 1, target)

# %% [markdown]
# ### Recurrence Relation
# T(n)=T(n/2)+O(1)
#
# ### Time Complexity
# O(log n)

# %% [markdown]
# ---
#
# # ⭐ What is the difference between T(n-1) and T(n/2)?
